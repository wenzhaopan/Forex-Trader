# %%
import requests
import defs

# %%
session = requests.Session()

# %%
instrument = "EUR_USD"
count = 10
granularity = "H1"

# %%
url = f"{defs.OANDA_URL}/instruments/{instrument}/candles"

# %%
url
# Out:
# 'https://api-fxpractice.oanda.com/v3/instruments/EUR_USD/candles'

# %%
params = dict(
    count = count,
    granularity = granularity,
    price = "MBA"
)

# %%
params
# Out:
# {'count': 10, 'granularity': 'H1', 'price': 'MBA'}

# %%
response = session.get(url, params = params, headers=defs.SECURE_HEADER)

# %%
response.status_code
# Out:
# 200

# %%
response.json()
# Out:
# {'instrument': 'EUR_USD',
#  'granularity': 'H1',
#  'candles': [{'complete': True,
#    'volume': 5158,
#    'time': '2025-01-09T16:00:00.000000000Z',
#    'bid': {'o': '1.02986', 'h': '1.03004', 'l': '1.02903', 'c': '1.02965'},
#    'mid': {'o': '1.02994', 'h': '1.03012', 'l': '1.02912', 'c': '1.02973'},
#    'ask': {'o': '1.03001', 'h': '1.03020', 'l': '1.02920', 'c': '1.02981'}},
#   {'complete': True,
#    'volume': 4049,
#    'time': '2025-01-09T17:00:00.000000000Z',
#    'bid': {'o': '1.02966', 'h': '1.03011', 'l': '1.02930', 'c': '1.02967'},
#    'mid': {'o': '1.02974', 'h': '1.03020', 'l': '1.02938', 'c': '1.02974'},
#    'ask': {'o': '1.02981', 'h': '1.03028', 'l': '1.02946', 'c': '1.02981'}},
#   {'complete': True,
#    'volume': 2290,
#    'time': '2025-01-09T18:00:00.000000000Z',
#    'bid': {'o': '1.02964', 'h': '1.03017', 'l': '1.02934', 'c': '1.02995'},
#    'mid': {'o': '1.02972', 'h': '1.03026', 'l': '1.02941', 'c': '1.03002'},
#    'ask': {'o': '1.02979', 'h': '1.03034', 'l': '1.02948', 'c': '1.03010'}},
#   {'complete': True,
#    'volume': 1710,
#    'time': '2025-01-09T19:00:00.000000000Z',
#    'bid': {'o': '1.02995', 'h': '1.03015', 'l': '1.02970', 'c': '1.02972'},
#    'mid': {'o': '1.03003', 'h': '1.03022', 'l': '1.02978', 'c': '1.02980'},
#    'ask': {'o': '1.03011', 'h': '1.03030', 'l': '1.02985', 'c': '1.02989'}},
#   {'complete': True,
#    'volume': 1614,
#    'time': '2025-01-09T20:00:00.000000000Z',
#    'bid': {'o': '1.02974', 'h': '1.03030', 'l': '1.02974', 'c': '1.03004'},
#    'mid': {'o': '1.02982', 'h': '1.03038', 'l': '1.02982', 'c': '1.03012'},
#    'ask': {'o': '1.02990', 'h': '1.03045', 'l': '1.02990', 'c': '1.03020'}},
#   {'complete': True,
#    'volume': 1062,
#    'time': '2025-01-09T21:00:00.000000000Z',
#    'bid': {'o': '1.03002', 'h': '1.03003', 'l': '1.02984', 'c': '1.02990'},
#    'mid': {'o': '1.03010', 'h': '1.03011', 'l': '1.02991', 'c': '1.02998'},
#    'ask': {'o': '1.03019', 'h': '1.03019', 'l': '1.02998', 'c': '1.03005'}},
#   {'complete': True,
#    'volume': 933,
#    'time': '2025-01-09T22:00:00.000000000Z',
#    'bid': {'o': '1.02986', 'h': '1.03005', 'l': '1.02957', 'c': '1.03003'},
#    'mid': {'o': '1.03008', 'h': '1.03020', 'l': '1.02976', 'c': '1.03017'},
#    'ask': {'o': '1.03030', 'h': '1.03049', 'l': '1.02989', 'c': '1.03031'}},
#   {'complete': True,
#    'volume': 1098,
#    'time': '2025-01-09T23:00:00.000000000Z',
#    'bid': {'o': '1.03001', 'h': '1.03008', 'l': '1.02949', 'c': '1.02959'},
#    'mid': {'o': '1.03016', 'h': '1.03020', 'l': '1.02957', 'c': '1.02967'},
#    'ask': {'o': '1.03032', 'h': '1.03034', 'l': '1.02965', 'c': '1.02975'}},
#   {'complete': True,
#    'volume': 3198,
#    'time': '2025-01-10T00:00:00.000000000Z',
#    'bid': {'o': '1.02961', 'h': '1.02997', 'l': '1.02914', 'c': '1.02949'},
#    'mid': {'o': '1.02968', 'h': '1.03006', 'l': '1.02922', 'c': '1.02956'},
#    'ask': {'o': '1.02976', 'h': '1.03014', 'l': '1.02931', 'c': '1.02964'}},
#   {'complete': False,
#    'volume': 2970,
#    'time': '2025-01-10T01:00:00.000000000Z',
#    'bid': {'o': '1.02948', 'h': '1.03038', 'l': '1.02928', 'c': '1.03027'},
#    'mid': {'o': '1.02956', 'h': '1.03046', 'l': '1.02936', 'c': '1.03035'},
#    'ask': {'o': '1.02964', 'h': '1.03054', 'l': '1.02945', 'c': '1.03043'}}]}
