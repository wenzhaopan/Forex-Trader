# %%
import requests
import defs
import pandas as pd

# %%
session = requests.Session()

# %%
url = f"{defs.OANDA_URL}/accounts/{defs.ACCOUNT_ID}/instruments"

# %%
url
# Out:
# 'https://api-fxpractice.oanda.com/v3/accounts/101-002-30781914-001/instruments'

# %%
response = session.get(url, params = None, headers=defs.SECURE_HEADER)

# %%
response.status_code
# Out:
# 200

# %%
data = response.json()
data.keys()
# Out:
# dict_keys(['instruments', 'lastTransactionID'])

# %%
instruments = data['instruments']
len(instruments)
# Out:
# 123

# %%
instruments[0].keys()
# Out:
# dict_keys(['name', 'type', 'displayName', 'pipLocation', 'displayPrecision', 'tradeUnitsPrecision', 'minimumTradeSize', 'maximumTrailingStopDistance', 'minimumTrailingStopDistance', 'maximumPositionSize', 'maximumOrderUnits', 'marginRate', 'guaranteedStopLossOrderMode', 'tags', 'financing'])

# %%
instrument_data = []
for item in instruments:
    new_ob = dict(
        name = item['name'],
        type = item['type'],
        displayName = item['displayName'],
        pipLocation = item['pipLocation'],
        marginRate = item['marginRate']
    )
    instrument_data.append(new_ob)

# %%
for item in instrument_data[0:3]:
    print(item)
# Out:
# {'name': 'XAG_SGD', 'type': 'METAL', 'displayName': 'Silver/SGD', 'pipLocation': -4, 'marginRate': '0.3'}
# {'name': 'AUD_NZD', 'type': 'CURRENCY', 'displayName': 'AUD/NZD', 'pipLocation': -4, 'marginRate': '0.06'}
# {'name': 'BCO_USD', 'type': 'CFD', 'displayName': 'Brent Crude Oil', 'pipLocation': -2, 'marginRate': '0.094'}

# %%
instrument_df = pd.DataFrame.from_dict(instrument_data)

# %%
instrument_df
# Out:
#          name      type      displayName  pipLocation marginRate
# 0     XAG_SGD     METAL       Silver/SGD           -4        0.3
# 1     AUD_NZD  CURRENCY          AUD/NZD           -4       0.06
# 2     BCO_USD       CFD  Brent Crude Oil           -2      0.094
# 3     NZD_USD  CURRENCY          NZD/USD           -4      0.045
# 4    CORN_USD       CFD             Corn           -2      0.115
# ..        ...       ...              ...          ...        ...
# 118   XAG_EUR     METAL       Silver/EUR           -4       0.23
# 119   AUD_JPY  CURRENCY          AUD/JPY           -2      0.069
# 120   EUR_ZAR  CURRENCY          EUR/ZAR           -4       0.28
# 121   CHF_ZAR  CURRENCY          CHF/ZAR           -4       0.28
# 122   USD_HKD  CURRENCY          USD/HKD           -4      0.115
#
# [123 rows x 5 columns]

# %%
instrument_df.to_pickle("instruments.pkl")
